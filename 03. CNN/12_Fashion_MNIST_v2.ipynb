# %% [markdown]
# # Fashion MNIST - CNN v1
# - 2 x Conv2D layers with padding
# - 1 MaxPooling 2D layer
# - 1 Dropout(0.25) layer
# - 1 FCN layer
# - 1 Dropout(0.5) layer
# - 1 Output layer

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
from tensorflow.keras.datasets import fashion_mnist
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
plt.imshow(X_train[0], cmap = "Greys")

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
plt.figure(figsize = (13,5))
for i in range(1, 11):
    plt.subplot(2, 5, i)
    plt.imshow(X_train[i], cmap = "Greys")
    plt.title(class_names[y_train[i]])
    plt.xticks([]), plt.yticks([])
plt.show()

# %%
# X_train, X_test 정규화(0 ~ 1), 이미지 차원 변경: 2차원 --> 1차원
X_train = X_train.reshape(-1, 28,28,1) / 255.
X_test = X_test.reshape(-1, 28,28,1) / 255.
X_train.shape, X_test.shape
# Out:
# ((60000, 28, 28, 1), (10000, 28, 28, 1))

# %%
# Onehot encoding
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
y_train.shape, y_test.shape
# Out:
# ((60000, 10), (10000, 10))

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
model = Sequential([
    Conv2D(32, kernel_size = (3,3), padding = "same", input_shape = (28, 28, 1), activation = "relu"),
    Conv2D(64, kernel_size = (3,3), padding = "same", activation = "relu"),
    MaxPooling2D(),     # MaxPooling2D(pool_size=(2,2))
    Dropout(0.25),
    Flatten(),
    Dense(512, activation = "relu"),
    Dropout(0.5),
    Dense(10, activation = "softmax")
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 64)        18496
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 64)       0
#  )
#
#  dropout (Dropout)           (None, 14, 14, 64)        0
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 512)               6423040
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 6,446,986
# Trainable params: 6,446,986
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = "adam",loss = "categorical_crossentropy", metrics = ["accuracy"])

# %%
model_path = "best-fasion-mnist-cnn-v1.h5"
mc = ModelCheckpoint(model_path, save_best_only=True, verbose = 1)
es = EarlyStopping(patience = 10)

# %%
hist = model.fit(X_train, y_train, validation_split = 0.2, epochs = 100,
                 batch_size = 200, callbacks = [mc, es], verbose = 1)
# Out:
# Epoch 1/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.4804 - accuracy: 0.8287
# Epoch 1: val_loss improved from inf to 0.30914, saving model to best-fasion-mnist-cnn-v1.h5
# 240/240 [==============================] - 16s 18ms/step - loss: 0.4797 - accuracy: 0.8289 - val_loss: 0.3091 - val_accuracy: 0.8884
# Epoch 2/100
# 240/240 [==============================] - ETA: 0s - loss: 0.3017 - accuracy: 0.8907
# Epoch 2: val_loss improved from 0.30914 to 0.26676, saving model to best-fasion-mnist-cnn-v1.h5
# 240/240 [==============================] - 4s 17ms/step - loss: 0.3017 - accuracy: 0.8907 - val_loss: 0.2668 - val_accuracy: 0.9014
# Epoch 3/100
# 237/240 [============================>.] - ETA: 0s - loss: 0.2470 - accuracy: 0.9104
# Epoch 3: val_loss improved from 0.26676 to 0.23116, saving model to best-fasion-mnist-cnn-v1.h5
# 240/240 [==============================] - 4s 17ms/step - loss: 0.2473 - accuracy: 0.9103 - val_loss: 0.2312 - val_accuracy: 0.9144
# Epoch 4/100
# 237/240 [============================>.] - ETA: 0s - loss: 0.2124 - accuracy: 0.9222
# Epoch 4: val_loss improved from 0.23116 to 0.21713, saving model to best-fasion-mnist-cnn-v1.h5
# 240/240 [==============================] - 4s 18ms/step - loss: 0.2125 - accuracy: 0.9221 - val_loss: 0.2171 - val_accuracy: 0.9203
# Epoch 5/100
# 240/240 [==============================] - ETA: 0s - loss: 0.1859 - accuracy: 0.9318
# Epoch 5: val_loss improved from 0.21713 to 0.20722, saving model to best-fasion-mnist-cnn-v1.h5
# 240/240 [==============================] - 4s 17ms/step - loss: 0.1859 - accuracy: 0.9318 - val_loss: 0.2072 - val_accuracy: 0.9237
# Epoch 6/100
# 237/240 [============================>.] - ETA: 0s - loss: 0.1633 - accuracy: 0.9407
# Epoch 6: val_loss improved from 0.20722 to 0.20339, saving model to best-fasion-mnist-cnn-v1.h5
# 240/240 [==============================] - 4s 18ms/step - loss: 0.1632 - accuracy: 0.9407 - val_loss: 0.2034 - val_accuracy: 0.9258
# Epoch 7/100
# 239/240 [============================>.] - ETA: 0s - loss: 0.1423 - accuracy: 0.9470
# Epoch 7: val_loss improved from 0.20339 to 0.20240, saving model to best-fasion-mnist-cnn-v1.h5
# 240/240 [==============================] - 4s 17ms/step - loss: 0.1426 - accuracy: 0.9468 - val_loss: 0.2024 - val_accuracy: 0.9292
# Epoch 8/100
# 237/240 [============================>.] - ETA: 0s - loss: 0.1248 - accuracy: 0.9541
# Epoch 8: val_loss did not improve from 0.20240
# 240/240 [==============================] - 4s 16ms/step - loss: 0.1252 - accuracy: 0.9539 - val_loss: 0.2075 - val_accuracy: 0.9283
# Epoch 9/100
# 237/240 [============================>.] - ETA: 0s - loss: 0.1126 - accuracy: 0.9586
# Epoch 9: val_loss improved from 0.20240 to 0.20052, saving model to best-fasion-mnist-cnn-v1.h5
# 240/240 [==============================] - 4s 17ms/step - loss: 0.1129 - accuracy: 0.9585 - val_loss: 0.2005 - val_accuracy: 0.9309
# Epoch 10/100
# 237/240 [============================>.] - ETA: 0s - loss: 0.0971 - accuracy: 0.9639
# Epoch 10: val_loss did not improve from 0.20052
# 240/240 [==============================] - 4s 17ms/step - loss: 0.0969 - accuracy: 0.9640 - val_loss: 0.2215 - val_accuracy: 0.9285
# Epoch 11/100
# 239/240 [============================>.] - ETA: 0s - loss: 0.0861 - accuracy: 0.9683
# Epoch 11: val_loss did not improve from 0.20052
# 240/240 [==============================] - 4s 16ms/step - loss: 0.0860 - accuracy: 0.9683 - val_loss: 0.2155 - val_accuracy: 0.9327
# Epoch 12/100
# 237/240 [============================>.] - ETA: 0s - loss: 0.0771 - accuracy: 0.9713
# Epoch 12: val_loss did not improve from 0.20052
# 240/240 [==============================] - 4s 17ms/step - loss: 0.0772 - accuracy: 0.9713 - val_loss: 0.2265 - val_accuracy: 0.9294
# Epoch 13/100
# 237/240 [============================>.] - ETA: 0s - loss: 0.0671 - accuracy: 0.9752
# Epoch 13: val_loss did not improve from 0.20052
# 240/240 [==============================] - 4s 16ms/step - loss: 0.0673 - accuracy: 0.9752 - val_loss: 0.2332 - val_accuracy: 0.9306
# Epoch 14/100
# 237/240 [============================>.] - ETA: 0s - loss: 0.0639 - accuracy: 0.9768
# Epoch 14: val_loss did not improve from 0.20052
# 240/240 [==============================] - 4s 17ms/step - loss: 0.0638 - accuracy: 0.9769 - val_loss: 0.2389 - val_accuracy: 0.9317
# Epoch 15/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0552 - accuracy: 0.9802
# Epoch 15: val_loss did not improve from 0.20052
# 240/240 [==============================] - 4s 18ms/step - loss: 0.0552 - accuracy: 0.9802 - val_loss: 0.2440 - val_accuracy: 0.9308
# Epoch 16/100
# 237/240 [============================>.] - ETA: 0s - loss: 0.0484 - accuracy: 0.9817
# Epoch 16: val_loss did not improve from 0.20052
# 240/240 [==============================] - 4s 16ms/step - loss: 0.0486 - accuracy: 0.9815 - val_loss: 0.2603 - val_accuracy: 0.9307
# Epoch 17/100
# 239/240 [============================>.] - ETA: 0s - loss: 0.0448 - accuracy: 0.9838
# Epoch 17: val_loss did not improve from 0.20052
# 240/240 [==============================] - 4s 16ms/step - loss: 0.0448 - accuracy: 0.9838 - val_loss: 0.2554 - val_accuracy: 0.9326
# Epoch 18/100
# 237/240 [============================>.] - ETA: 0s - loss: 0.0406 - accuracy: 0.9848
# Epoch 18: val_loss did not improve from 0.20052
# 240/240 [==============================] - 4s 16ms/step - loss: 0.0406 - accuracy: 0.9848 - val_loss: 0.2531 - val_accuracy: 0.9346
# Epoch 19/100
# 237/240 [============================>.] - ETA: 0s - loss: 0.0351 - accuracy: 0.9873
# Epoch 19: val_loss did not improve from 0.20052
# 240/240 [==============================] - 4s 16ms/step - loss: 0.0350 - accuracy: 0.9873 - val_loss: 0.2894 - val_accuracy: 0.9292

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2195 - accuracy: 0.9251
# [0.21946321427822113, 0.9251000285148621]

# %%
y_acc = hist.history["accuracy"]
y_vloss = hist.history["val_loss"]
xs = np.arange(1, len(y_acc) + 1)

# %%
plt.figure(figsize = (12,8))
plt.plot(xs, y_acc, label = "Accuracy")
plt.plot(xs, y_vloss, label = "Validation loss")
plt.legend(), plt.grid(), plt.xlabel("Epoch"), plt.title("Fashion MNIST CNN model v1")
plt.show()
