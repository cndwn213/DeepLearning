# %% [markdown]
# # Fashion MNIST - CNN v1
# - 2 x Conv2D layers
# - 1 MaxPooling 2D layer
# - 1 Dropout(0.25) layer
# - 1 FCN layer
# - 1 Dropout(0.5) layer
# - 1 Output layer

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
from tensorflow.keras.datasets import fashion_mnist
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
plt.imshow(X_train[0], cmap = "Greys")

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
plt.figure(figsize = (13,5))
for i in range(1, 11):
    plt.subplot(2, 5, i)
    plt.imshow(X_train[i], cmap = "Greys")
    plt.title(class_names[y_train[i]])
    plt.xticks([]), plt.yticks([])
plt.show()

# %%
# X_train, X_test 정규화(0 ~ 1), 이미지 차원 변경: 2차원 --> 1차원
X_train = X_train.reshape(-1, 28,28,1) / 255.
X_test = X_test.reshape(-1, 28,28,1) / 255.
X_train.shape, X_test.shape
# Out:
# ((60000, 28, 28, 1), (10000, 28, 28, 1))

# %%
# Onehot encoding
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
y_train.shape, y_test.shape
# Out:
# ((60000, 10), (10000, 10))

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
model = Sequential([
    Conv2D(32, kernel_size = (3,3), input_shape = (28, 28, 1), activation = "relu"),
    Conv2D(64, kernel_size = (3,3), activation = "relu"),
    MaxPooling2D(),     # MaxPooling2D(pool_size=(2,2))
    Dropout(0.25),
    Flatten(),
    Dense(512, activation = "relu"),
    Dropout(0.5),
    Dense(10, activation = "softmax")
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 64)        18496
#
#  max_pooling2d (MaxPooling2D  (None, 12, 12, 64)       0
#  )
#
#  dropout (Dropout)           (None, 12, 12, 64)        0
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 512)               4719104
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 4,743,050
# Trainable params: 4,743,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = "adam",loss = "categorical_crossentropy", metrics = ["accuracy"])

# %%
model_path = "best-fasion-mnist-cnn-v1.h5"
mc = ModelCheckpoint(model_path, save_best_only=True, verbose = 1)
es = EarlyStopping(patience = 10)

# %%
hist = model.fit(X_train, y_train, validation_split = 0.2, epochs = 100,
                 batch_size = 200, callbacks = [mc, es], verbose = 1)
# Out:
# Epoch 1/100
# 240/240 [==============================] - ETA: 0s - loss: 0.5014 - accuracy: 0.8216
# Epoch 1: val_loss improved from inf to 0.32245, saving model to best-fasion-mnist-cnn-v1.h5
# 240/240 [==============================] - 15s 15ms/step - loss: 0.5014 - accuracy: 0.8216 - val_loss: 0.3225 - val_accuracy: 0.8842
# Epoch 2/100
# 239/240 [============================>.] - ETA: 0s - loss: 0.3139 - accuracy: 0.8879
# Epoch 2: val_loss improved from 0.32245 to 0.27746, saving model to best-fasion-mnist-cnn-v1.h5
# 240/240 [==============================] - 3s 15ms/step - loss: 0.3138 - accuracy: 0.8880 - val_loss: 0.2775 - val_accuracy: 0.8973
# Epoch 3/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.2599 - accuracy: 0.9057
# Epoch 3: val_loss improved from 0.27746 to 0.23743, saving model to best-fasion-mnist-cnn-v1.h5
# 240/240 [==============================] - 4s 15ms/step - loss: 0.2605 - accuracy: 0.9055 - val_loss: 0.2374 - val_accuracy: 0.9103
# Epoch 4/100
# 236/240 [============================>.] - ETA: 0s - loss: 0.2254 - accuracy: 0.9172
# Epoch 4: val_loss improved from 0.23743 to 0.22945, saving model to best-fasion-mnist-cnn-v1.h5
# 240/240 [==============================] - 4s 15ms/step - loss: 0.2256 - accuracy: 0.9172 - val_loss: 0.2295 - val_accuracy: 0.9140
# Epoch 5/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.2012 - accuracy: 0.9254
# Epoch 5: val_loss did not improve from 0.22945
# 240/240 [==============================] - 3s 14ms/step - loss: 0.2011 - accuracy: 0.9254 - val_loss: 0.2310 - val_accuracy: 0.9151
# Epoch 6/100
# 240/240 [==============================] - ETA: 0s - loss: 0.1802 - accuracy: 0.9344
# Epoch 6: val_loss improved from 0.22945 to 0.20925, saving model to best-fasion-mnist-cnn-v1.h5
# 240/240 [==============================] - 3s 14ms/step - loss: 0.1802 - accuracy: 0.9344 - val_loss: 0.2093 - val_accuracy: 0.9228
# Epoch 7/100
# 240/240 [==============================] - ETA: 0s - loss: 0.1568 - accuracy: 0.9408
# Epoch 7: val_loss improved from 0.20925 to 0.20585, saving model to best-fasion-mnist-cnn-v1.h5
# 240/240 [==============================] - 3s 14ms/step - loss: 0.1568 - accuracy: 0.9408 - val_loss: 0.2059 - val_accuracy: 0.9267
# Epoch 8/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.1398 - accuracy: 0.9481
# Epoch 8: val_loss improved from 0.20585 to 0.20247, saving model to best-fasion-mnist-cnn-v1.h5
# 240/240 [==============================] - 3s 14ms/step - loss: 0.1405 - accuracy: 0.9480 - val_loss: 0.2025 - val_accuracy: 0.9273
# Epoch 9/100
# 240/240 [==============================] - ETA: 0s - loss: 0.1272 - accuracy: 0.9529
# Epoch 9: val_loss improved from 0.20247 to 0.20020, saving model to best-fasion-mnist-cnn-v1.h5
# 240/240 [==============================] - 3s 14ms/step - loss: 0.1272 - accuracy: 0.9529 - val_loss: 0.2002 - val_accuracy: 0.9290
# Epoch 10/100
# 240/240 [==============================] - ETA: 0s - loss: 0.1107 - accuracy: 0.9589
# Epoch 10: val_loss did not improve from 0.20020
# 240/240 [==============================] - 3s 14ms/step - loss: 0.1107 - accuracy: 0.9589 - val_loss: 0.2179 - val_accuracy: 0.9258
# Epoch 11/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0959 - accuracy: 0.9647
# Epoch 11: val_loss did not improve from 0.20020
# 240/240 [==============================] - 3s 14ms/step - loss: 0.0959 - accuracy: 0.9646 - val_loss: 0.2130 - val_accuracy: 0.9291
# Epoch 12/100
# 239/240 [============================>.] - ETA: 0s - loss: 0.0882 - accuracy: 0.9671
# Epoch 12: val_loss did not improve from 0.20020
# 240/240 [==============================] - 4s 15ms/step - loss: 0.0883 - accuracy: 0.9671 - val_loss: 0.2161 - val_accuracy: 0.9301
# Epoch 13/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0781 - accuracy: 0.9710
# Epoch 13: val_loss did not improve from 0.20020
# 240/240 [==============================] - 3s 14ms/step - loss: 0.0781 - accuracy: 0.9710 - val_loss: 0.2236 - val_accuracy: 0.9298
# Epoch 14/100
# 238/240 [============================>.] - ETA: 0s - loss: 0.0727 - accuracy: 0.9737
# Epoch 14: val_loss did not improve from 0.20020
# 240/240 [==============================] - 3s 14ms/step - loss: 0.0726 - accuracy: 0.9737 - val_loss: 0.2383 - val_accuracy: 0.9292
# Epoch 15/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0686 - accuracy: 0.9754
# Epoch 15: val_loss did not improve from 0.20020
# 240/240 [==============================] - 3s 14ms/step - loss: 0.0686 - accuracy: 0.9754 - val_loss: 0.2325 - val_accuracy: 0.9286
# Epoch 16/100
# 239/240 [============================>.] - ETA: 0s - loss: 0.0618 - accuracy: 0.9773
# Epoch 16: val_loss did not improve from 0.20020
# 240/240 [==============================] - 3s 14ms/step - loss: 0.0618 - accuracy: 0.9773 - val_loss: 0.2368 - val_accuracy: 0.9306
# Epoch 17/100
# 239/240 [============================>.] - ETA: 0s - loss: 0.0536 - accuracy: 0.9807
# Epoch 17: val_loss did not improve from 0.20020
# 240/240 [==============================] - 3s 14ms/step - loss: 0.0535 - accuracy: 0.9808 - val_loss: 0.2449 - val_accuracy: 0.9283
# Epoch 18/100
# 240/240 [==============================] - ETA: 0s - loss: 0.0508 - accuracy: 0.9805
# Epoch 18: val_loss did not improve from 0.20020
# 240/240 [==============================] - 3s 14ms/step - loss: 0.0508 - accuracy: 0.9805 - val_loss: 0.2533 - val_accuracy: 0.9297
# Epoch 19/100
# 239/240 [============================>.] - ETA: 0s - loss: 0.0467 - accuracy: 0.9829
# Epoch 19: val_loss did not improve from 0.20020
# 240/240 [==============================] - 3s 14ms/step - loss: 0.0466 - accuracy: 0.9830 - val_loss: 0.2570 - val_accuracy: 0.9299

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2160 - accuracy: 0.9258
# [0.21596497297286987, 0.9258000254631042]

# %%
y_acc = hist.history["accuracy"]
y_vloss = hist.history["val_loss"]
xs = np.arange(1, len(y_acc) + 1)

# %%
plt.figure(figsize = (12,8))
plt.plot(xs, y_acc, label = "Accuracy")
plt.plot(xs, y_vloss, label = "Validation loss")
plt.legend(), plt.grid(), plt.xlabel("Epoch"), plt.title("Fashion MNIST CNN model v1")
plt.show()
